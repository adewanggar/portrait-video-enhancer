# %% [markdown]
# # 🎬 Portrait Video Enhancer — Google Colab
#
# Enhance human portrait videos (facial fidelity, skin details, clothing, and outfits) using deep learning on Google Colab GPU (T4 / V100 / A100).
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/adewanggar/portrait-video-enhancer/blob/main/portrait_video_enhancer_colab.ipynb)
#
# ---
#
# ### ⚠️ Prerequisite: Enable GPU in Colab
# Before running the cells, make sure a GPU accelerator is active:
# 1. Go to **Runtime** (Menu bar) -> **Change runtime type**.
# 2. Under **Hardware accelerator**, select **T4 GPU** (free tier) or higher.
# 3. Click **Save**.

# %%
# Step 1: Verify GPU Allocation
# !nvidia-smi

# %%
# Step 2: Clone Repository & Enter Directory
import os
if not os.path.exists('portrait-video-enhancer'):
    # !git clone https://github.com/adewanggar/portrait-video-enhancer.git
# %cd portrait-video-enhancer
# !git pull

# %%
# Step 3: Install Dependencies & Apply Compatibility Patch
# Note: basicsr requires --no-build-isolation in modern PyTorch environments
# !pip install basicsr --no-build-isolation || pip install --no-build-isolation git+https://github.com/XPixelGroup/BasicSR.git
# !pip install -r requirements.txt
# !python fix_basicsr.py

# %%
# Step 4: Download AI Model Weights
# Downloads CodeFormer, facelib, Real-ESRGAN, GFPGAN, and RIFE
# !python download_models.py --all

# %%
# Step 5: Launch Application with Gradio Public URL
# Click the generated *.gradio.live link below to open the interface!
# !python app.py --share
